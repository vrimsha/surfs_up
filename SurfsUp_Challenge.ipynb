# %%
# Dependencies
import numpy as np
import pandas as pd

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function.
from sqlalchemy import extract

# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
temperature1 = session.query(Measurement.tobs).filter(extract('month', Measurement.date) == 6)

# %%
#  3. Convert the June temperatures to a list.
temperature_list =[]
for t in temperature1 :
    temperature_list.append(t)
print(temperature_list)
# Out:
# [(78.0,), (76.0,), (78.0,), (76.0,), (77.0,), (78.0,), (77.0,), (78.0,), (78.0,), (79.0,), (78.0,), (78.0,), (78.0,), (77.0,), (78.0,), (78.0,), (77.0,), (77.0,), (82.0,), (78.0,), (78.0,), (78.0,), (78.0,), (78.0,), (77.0,), (76.0,), (78.0,), (78.0,), (78.0,), (78.0,), (77.0,), (78.0,), (73.0,), (70.0,), (76.0,), (77.0,), (77.0,), (77.0,), (77.0,), (78.0,), (77.0,), (77.0,), (78.0,), (78.0,), (77.0,), (78.0,), (78.0,), (75.0,), (76.0,), (76.0,), (77.0,), (78.0,), (76.0,), (77.0,), (75.0,), (77.0,), (76.0,), (76.0,), (75.0,), (77.0,), (77.0,), (76.0,), (78.0,), (77.0,), (76.0,), (77.0,), (76.0,), (76.0,), (77.0,), (77.0,), (78.0,), (77.0,), (77.0,), (77.0,), (76.0,), (75.0,), (76.0,), (76.0,), (77.0,), (76.0,), (73.0,), (73.0,), (75.0,), (77.0,), (76.0,), (77.0,), (79.0,), (78.0,), (79.0,), (78.0,), (78.0,), (79.0,), (77.0,), (77.0,), (77.0,), (77.0,), (77.0,), (78.0,), (77.0,), (76.0,), (78.0,), (78.0,), (77.0,), (78.0,), (78.0,), (73.0,), (76.0,), (77.0,), (75.0,), (76.0,), (74.0,)
# ...

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June. 
temperature_df = pd.DataFrame(temperature_list)
print(temperature_df)
# Out:
#       tobs
# 0     78.0
# 1     76.0
# 2     78.0
# 3     76.0
# 4     77.0
# ...    ...
# 1695  79.0
# 1696  74.0
# 1697  74.0
# 1698  76.0
# 1699  75.0
#
# [1700 rows x 1 columns]

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.
temperature_df.describe()
# Out:
#               tobs
# count  1700.000000
# mean     74.944118
# std       3.257417
# min      64.000000
# 25%      73.000000
# 50%      75.000000
# 75%      77.000000
# max      85.000000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
temperature2 = session.query(Measurement.tobs).filter(extract('month', Measurement.date) == 12)

# %%
# 7. Convert the December temperatures to a list.
temperature_list2 =[]
for t in temperature2 :
    temperature_list2.append(t)
print(temperature_list2)
# Out:
# [(76.0,), (74.0,), (74.0,), (64.0,), (64.0,), (67.0,), (77.0,), (66.0,), (69.0,), (68.0,), (68.0,), (71.0,), (74.0,), (67.0,), (66.0,), (69.0,), (71.0,), (70.0,), (70.0,), (74.0,), (74.0,), (71.0,), (75.0,), (75.0,), (72.0,), (69.0,), (68.0,), (73.0,), (74.0,), (73.0,), (73.0,), (73.0,), (73.0,), (71.0,), (73.0,), (73.0,), (77.0,), (72.0,), (71.0,), (73.0,), (70.0,), (73.0,), (69.0,), (74.0,), (72.0,), (71.0,), (72.0,), (72.0,), (70.0,), (73.0,), (73.0,), (72.0,), (73.0,), (73.0,), (72.0,), (63.0,), (65.0,), (71.0,), (76.0,), (70.0,), (76.0,), (69.0,), (69.0,), (69.0,), (74.0,), (76.0,), (74.0,), (73.0,), (73.0,), (74.0,), (73.0,), (73.0,), (73.0,), (74.0,), (74.0,), (71.0,), (73.0,), (72.0,), (64.0,), (66.0,), (73.0,), (72.0,), (65.0,), (64.0,), (69.0,), (68.0,), (77.0,), (71.0,), (71.0,), (69.0,), (68.0,), (68.0,), (69.0,), (70.0,), (72.0,), (76.0,), (75.0,), (69.0,), (71.0,), (71.0,), (71.0,), (68.0,), (65.0,), (70.0,), (69.0,), (69.0,), (71.0,), (67.0,), (73.0,), (74.0,), (73.0,)
# ...

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
temperature_df2 = pd.DataFrame(temperature_list2)
print(temperature_df2)
# Out:
#       tobs
# 0     76.0
# 1     74.0
# 2     74.0
# 3     64.0
# 4     64.0
# ...    ...
# 1512  71.0
# 1513  71.0
# 1514  69.0
# 1515  65.0
# 1516  65.0
#
# [1517 rows x 1 columns]

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
temperature_df2.describe()
# Out:
#               tobs
# count  1517.000000
# mean     71.041529
# std       3.745920
# min      56.000000
# 25%      69.000000
# 50%      71.000000
# 75%      74.000000
# max      83.000000

# %% [markdown]
# ## D3: Determine the Rain Statistics in June and December

# %%
# Rain data of June.
rain_june = session.query(Measurement.prcp).filter(extract('month', Measurement.date) == 6)
rain_june_list =[]
for r in rain_june :
   rain_june_list.append(r)
#print(rain_june_list)
rain_june_df = pd.DataFrame(rain_june_list)
print(rain_june_df)
# Out:
#       prcp
# 0     0.00
# 1     0.01
# 2     0.00
# 3     0.00
# 4     0.00
# ...    ...
# 1695  0.02
# 1696  0.10
# 1697  0.02
# 1698  0.04
# 1699  0.20
#
# [1700 rows x 1 columns]

# %%
rain_june_df.describe()
# Out:
#               prcp
# count  1574.000000
# mean      0.136360
# std       0.335731
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.120000
# max       4.430000

# %%
rain_june_df.plot()
# Out:
# <AxesSubplot:>

# %%
# Rain data of December.
rain_dec = session.query(Measurement.prcp).filter(extract('month', Measurement.date) == 12)
rain_dec_list =[]
for r in rain_dec :
   rain_dec_list.append(r)
#print(rain_june_list)
rain_dec_df = pd.DataFrame(rain_dec_list)
print(rain_dec_df)
# Out:
#       prcp
# 0     0.04
# 1     0.00
# 2     0.00
# 3     0.00
# 4     0.00
# ...    ...
# 1512  0.14
# 1513  0.14
# 1514  1.03
# 1515  2.37
# 1516  0.90
#
# [1517 rows x 1 columns]

# %%
rain_dec_df.describe()
# Out:
#               prcp
# count  1405.000000
# mean      0.216819
# std       0.541399
# min       0.000000
# 25%       0.000000
# 50%       0.030000
# 75%       0.150000
# max       6.420000

# %%
rain_dec_df.plot()
# Out:
# <AxesSubplot:>
